# %%
class Cafe :
    
    def __init__(self) :
        self.table_List = list()
        self.menu_List = list()
        self.dagi_List = list()
        self.name = ""
    
    def get_Name(self) :
        return self.name
    
    def set_Name(self) :
        name = input("가게 이름 : ")
        self.name = name
        
    def get_Table(self) :
        return self.table_List
    
    def set_Table(self) :
        n = int(input("테이블 개수"))
        for i in range(1, n+1) :
            self.get_Table().append([i,0])
        
        
# 매뉴 ------------------------------------------------------------------

    def get_Menu(self) :
        return self.menu_List
    
    def selet_Menu(self) :
        print("-"*20)
        print("이름      가격")
        for menu in self.get_Menu() :
            print("%s %10s원" %(menu[0],menu[1]))
        print("-"*20)
        
    def set_Menu(self) :
        print("="*20)
        print("메뉴 추가 : 0 = 종료")
        print("-"*20)
        while True :
            menu = input("메뉴 이름 : ")
            if menu == "0" :
                self.selet_Menu()
                break
            
            else :
                price = int(input("가격 설정 : "))
                self.get_Menu().append([menu, price])
                print("= 메뉴가 추가 되었습니다 =\n")
                
# 주문 --------------------------------------------------------------



    
# 대기 --------------------------------------------------------------

    def get_dagi(self) :
        return self.dagi_List    
    
    def server_start(self) :
        print("")
    
    def get_LenTable(self) :
        num = len(get_Table())
        return num
    
    def table_Check(self) :
        for table in get_Table() :
            if table[1] == 0 :
                pass
        
    def full_Check(self) :
        pass

    
#--------------------------------------------------------------------

    def seting(self) :
        print("="*20)
        print("1. 가게 Open\n2. 영업 시작\n3. 작업 종료")
        print("="*20)
        
        num = int(input("선택 = "))
        if num == 1 :
            self.set_Name()
            self.set_Menu()
            self.set_Table()
            
        elif num == 2 :
            pass
        
        elif num == 3 :
            pass
