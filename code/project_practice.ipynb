# %%
class Cafe:
    
    def __init__(self):
        self.name = ""
        self.menu_List = list()
        self.stay_List = list()
        self.table_List = list()
        
    def get_Name(self):               
        return self.name               
    
    def set_Name(self):
        name = input("상호명 :")
        self.name = name
        
    def get_Menu(self):
        return self.menu_List
    
    # Menu
    
    def select_Menu(self):
        print("-"*30)
        print("번호     메뉴     금액")
        for menu in self.get_Menu():
            print("%s %10s %10s원" %(menu[0], menu[1], menu[2]))
        print("-"*30)
    
    def set_Menu(self):
        print("-- < %s > --" %self.get_Name())
        print("-"*30)
        print("메뉴 추가 : 0 = 종료")
        print("-"*30)
        
        num = 0
        while True :
            menu = input("menu :")
            if menu == "0" :
                break
                
            else :
                self.menu_List = menu
                num+=1
                price = int(input("price : "))
                self.get_Menu().append([num,menu,price])
                print("= 메뉴 추가가 완료되었습니다. =\n")
    
    # stay
    
    def get_Stay(self):
        return self.stay_List
    
    def get_LenStay(self):
        return len(self.get_stay())
    
    def set_Stay(self):
        s = int(input("대기 :"))
        for i in range(1, n+1):
            self.get_Stay().append([i, 0, []])
            
    def add_cust(self):
        if self.full_Check() == True:
            stay_number = len(self.get_stay())
            print("자리가 없습니다. 앞에 대기중인 손님 %d명" %stay_number)
            self.get_stay().append("cust")
            
            
    def full_Check(self):
        count = 0
        for i in self.get_Table():
            if i[1] == 1:
                count += 1
                
        if count == len(self.get_Table()):
            return True
        
    def get_Table(self):
        return self.table_List
    
    def set_Table(self):
        n = int(input("테이블 개수 = "))
        for i in range(1, n+1) :
            self.get_Table().append([i, 0, []])
            
    def check_In(self):
        for table in self.get_Table():
            domain = len(self.get_Menu())
            self.select_Menu()
        
    def check_Out(self):
        tableNumber = int(input("결제 - 테이블 번호")) # 이 부분에 계속 에러 발생함
    
    def select_Receipt(self, table, menu_List):
        print("===== 영수증 =====")
        print("---" + self.get_Name() + "---") # 상호명을 영수증에 출력
        print("메뉴                금액")
        num = 0
        tot = 0
        []
        for i in table: # 여기서도 계속 에러 발생
            
    def init(self):
        self.table_List = []
        self.menu_List = []
        self.stay_List = []
        self.name = ""
        
    def rename(self):
        self.menu_List = []
        self.set_Menu()        
        
    def seting(self) :
        
        while True :
            print()
            print("="*40)
            print("1. 가게 open\n2. 테이블 조회\n3. 고객 추가\n4. 고객 결제\n5. 상호 변경\n6. 작업 종료")
            print("="*40)
            num = int(input("선택"))
            
            if num == 1 :
                self.set_Name()
                self.set_Menu()
                self.set_Table()
                
            elif num == 2 :
                print("\n>------- 테이블 현황 -------<\n")
                
                for table in self.get_Table():
                    if table in self.get_Table():
                        print("   - 테이블[%d] (%s)" %(table[0], "사용중"))
                    else:
                        print("   - 테이블[%d] (%s)" %(table[0], "비어있음"))
                        
                print("\n>------- 대기줄 현황 -------<\n")
                
                if len(self.get_stay()) == 0:
                    print("    - 대기 없음 ")
                    
                else:
                    print("    - ", self.get_stay())
                
            elif num == 3:
                self.add_cust()
            
            elif num == 4:
                self.check_Out()
            
            elif num == 5:
                self.init()
                self.set_Name()
                self.set_Menu()
                self.set_Stay()
                self.set_Table()   
            
            elif num == 6:
                self.rename()    
                
            elif num == 7:
                break
# Out:
#   Input In [25]
#     def init(self):
#     ^
# IndentationError: expected an indented block

# %%
a = Cafe()
a.seting()
# Out:
# ========================================
# 1. 가게 open
# 2. 테이블 조회
# 3. 고객 추가
# 4. 고객 결제
# 5. 상호 변경
# 6. 작업 종료
# ========================================
# 선택1
# 상호명 :qq
# menu :www
# price : eee
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 a = Cafe()
# ----> 2 a.seting()
#
# Input In [1], in Cafe.seting(self)
#      88 if num == 1 :
#      89     self.set_Name()
# ---> 90     self.set_Menu()
#      91     self.set_Table()
#      93 elif num == 2 :
#
# Input In [1], in Cafe.set_Menu(self)
#      39 self.menu_List = menu
#      40 num+=1
# ---> 41 price = int(input("price : "))
#      42 self.get_Menu().append([num,menu,price])
#      43 print("= 메뉴 추가가 완료되었습니다. =\n")
#
# ValueError: invalid literal for int() with base 10: 'eee'

# %% [raw]
# print(a.get_Menu())
# print(a.get_Table())
# print(a.get_Stay())

# %%
a = Cafe()

# %%
    def table_check(self):
        for table in self.get_Table():
            
        print("")

# %%
class A :
    init__
    
    def mune()
    
        num = input
        if num == 1
            self.add_cust()
            self.add_manu()
            
        elif num == 2
            pass
        
        elif num == 3
            pass
        
        elif num == 4
            pass
        
        elif num == 5
            break
